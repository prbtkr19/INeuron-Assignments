# %% [markdown]
# # 1. How do you distinguish between shutil.copy() and shutil.copytree()?
#
# - shutil. copy() will copy a single file.
# - shutil. copytree() will copy an entire folder and every folder and file contained in it

# %% [markdown]
# # 2. What function is used to rename files??
#
# - os. rename() method in Python is used to rename a file or directory

# %% [markdown]
# # 3. What is the difference between the delete functions in the send2trash and shutil modules?
#
# - The send2trash functions will move a file or folder to the recycle bin,
# - while shutil functions will permanently delete files and folders

# %% [markdown]
# # 4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?
#
# - The zipfile. ZipFile() function is equivalent to the open() function;
# - the first argument is the filename, and the second argument is the mode to open the ZIP file in (read, write, or append).

# %% [markdown]
# # 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %%
#Python method walk() generates the file names in a directory tree by walking the tree either top-down or bottom-up.
import os
for root, dirs, files in os.walk(".", topdown=False):
   for name in files:
      print(os.path.join(root, name))
   for name in dirs:
      print(os.path.join(root, name))
# Out:
# .\.ipynb_checkpoints\Assignment_10_Solution-checkpoint.ipynb
# .\.ipynb_checkpoints\Assignment_7_Solution-checkpoint.ipynb
# .\.ipynb_checkpoints\Assignment_8_Solution-checkpoint.ipynb
# .\.ipynb_checkpoints\Assignment_9_Solution-checkpoint.ipynb
# .\assignment1_solution.ipynb
# .\Assignments_5_Solution.ipynb
# .\Assignment_10_Solution.ipynb
# .\Assignment_2_Solution.ipynb
# .\Assignment_3_solution.ipynb
# .\Assignment_4_Solution.ipynb
# .\Assignment_6_Solution.ipynb
# .\Assignment_7_Solution.ipynb
# .\Assignment_8_Solution.ipynb
# .\Assignment_9_Solution.ipynb
# .\picture3.pdf
# .\test.txt
# .\.ipynb_checkpoints

# %%
a= os.walk('C:\\Users\\prabh\\OneDrive\\Desktop', topdown=True, onerror=None, followlinks=False)
print(a)
for i in a:
    print(i)
# Out:
# <generator object walk at 0x000001C480040890>
# ('C:\\Users\\prabh\\OneDrive\\Desktop', ['AI_ppt', 'change-detection', 'INEURON', 'multi-cam-threading', 'new folder', 'New folder (2)', 'Nvidia-GPU-Cheatsheet', 'Python-w3-school', 'tyrone', 'web development', 'web_based_flask', 'web_based_flask1'], ['AI-lab-Hard-infra.pptx', 'desktop.ini', 'MTS_advt.pdf', 'MTS_curtainraiser_0.pdf', 'rnt_link_2022.pdf'])
# ('C:\\Users\\prabh\\OneDrive\\Desktop\\AI_ppt', ['AI Images'], ['1_enzZrRQ_EwtfJJKOffrcFg.png', 'AI_PPT.pptx', 'AI_PPt2.pptx', 'ALMLDL-01.jpg', 'applications-of-ai.jpg', 'applications-of-ai.png', 'artificial-intelligence-basic-ppt-5-1024.webp', 'c01657_90fce25e3a15402584c08d46d8a57ffe_mv2.png', 'chatbot.png', 'History-of-Artificial-Intelligence-1200x720.jpg', 'image-2.jpg', 'Picture2 (1).png', 'types-of-Artificial-intelligence.jpg', 'unnamed.png'])
# ...

# %%
import shutil
def searchfolder():
    a= os.walk(".", topdown=False,onerror=None, followlinks=False)
    for folderName, subfolders, filenames in a:
        for filename in filenames:
            if filename.endswith('.pdf'):
                shutil.copy(os.path.join(folderName, filename), 'C:\\Users\\prabh\\OneDrive\\Desktop\\images')

# %%
searchfolder()
